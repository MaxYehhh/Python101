# %% [markdown]
# <p style="font-size:30px;font-weight:bold;margin-top:-0px">Python 101</p>
# <p style="font-size:25px;font-weight:bold;">Project ─ PTT 爬蟲</p>
# <hr style="border:1px solid #edf1f2;" />
#
# > **概念**
# >- 讓程式模仿一個普通使用者的樣子。
# >1. 連線到特定網址，抓取資料。
# >2. 根據資料型態解析資料，取得實際想要的部分。
#
# ----
# Ref：

# %% [markdown]
# # Tools

# %%
# basic
import datetime as dt
import pandas as pd

# crawler
import requests
from bs4 import BeautifulSoup

# gsheet
import pygsheets
import modules.settings as s

# settings
pd.options.display.max_columns=None
pd.set_option('max_colwidth', None)  # 設定 value 顯示長度

# %% [markdown]
# # 開發
#
# **爬取每日熱門文章。**
#
# > **爬取資訊**
#     >- 看板
#     >- 文章標題
#     >- 作者
#     >- 發文時間
#     >- 文章連結
#     >- 推文數
#     >- 推文內容
#
# > **資訊位置**
#     >- 'div', 'r-ent'
#     - 文章標題
#
# > **流程**
# >1. 輸入URL，獲取網頁原始碼
# >2. 透過 BeautifulSoup 解析 HTML 格式文件
# >3. 從最新頁面開始爬取
#     - 設定爬取條件
#     - 將需求資訊以 dict 儲存
#     - return 上一頁 URL
# >4. 往上一頁爬取（設定爬取條件）

# %% [markdown]
# ## 步驟拆解

# %%
url = "https://www.ptt.cc/bbs/NBA/index.html"

### 1. 取得 response
r = requests.get(url)  # cookies={'over18': '1'}

### 2. 透過 parser 轉換成 BeautifulSoup 比較好處理的格式（以 BeautifulSoup 解析 HTML 格式文件）
"""
    - soup 是獲得的文件物件, html.parser 是支援的 parser.
    - 關於 parser, 比較常見的 parser 有這些：html.parser / html5lib / lxml。
    
    - BeautifulSoup 會根據指定的 parser 把文件轉換成一個複雜的樹形結構，每個節點都是 Python 物件。
        - 所有物件大致上可歸類為 4 種:
            - BeautifulSoup: 表示一個文件的所有內容.
            - Tag: 基本上就是 HTML 裡的各種 tag(div, p, etc...). 每個 tag 有兩個重要的屬性: 
                - name: 即 tag 的名字或著 tag 本身的 name.
                - attrs: 通常指一個 tag 的 class(常用).
            - NavigableString: 取得 tag 內的文字, 如: soup.p.string
            - Comment: 此物件是一個特殊的 NavigableString 物件, 其輸出的內容不包含註解符號.
"""
soup = BeautifulSoup(r.text, "html.parser")

### 3. Results
print('status_code: ', r.status_code)
# print('未解析資料： ', r.text)
print('解析後資料：', soup)
# Out:
# status_code:  200
# 解析後資料： <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/NBA/index.html">看板</a>
# <a class="btn" href="/man/NBA/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/NBA/index6508.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/NBA/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">84</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644365387.A.A5C.html">[Live] 青賽 @ 籃網</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E9%9D%92%E8%B3%BD+%40+%E7%B1%83%E7%B6%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">18</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644366520.A.4BD.html">Re: [討論] 拓荒者幹大事？</a>
# </div>
# <div class="meta">
# <div class="author">CW4</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E6%8B%93%E8%8D%92%E8%80%85%E5%B9%B9%E5%A4%A7%E4%BA%8B%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ACW4">搜尋看板內 CW4 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644366603.A.885.html">[Live] 快艇 @ 灰熊</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E5%BF%AB%E8%89%87+%40+%E7%81%B0%E7%86%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644366605.A.9D2.html">[Live] 火箭 @ 鵜鶘</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E7%81%AB%E7%AE%AD+%40+%E9%B5%9C%E9%B6%98">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">60</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644368426.A.DBE.html">[Live] 活塞 @ 獨行俠</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E6%B4%BB%E5%A1%9E+%40+%E7%8D%A8%E8%A1%8C%E4%BF%A0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644368896.A.045.html">[情報] NBA史上前15名的教練</a>
# </div>
# <div class="meta">
# <div class="author">ckurryobe</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA%E5%8F%B2%E4%B8%8A%E5%89%8D15%E5%90%8D%E7%9A%84%E6%95%99%E7%B7%B4">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Ackurryobe">搜尋看板內 ckurryobe 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">48</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644369223.A.966.html">[情報] 三分球大賽/技巧挑戰賽名單</a>
# </div>
# <div class="meta">
# <div class="author">love1500274</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E4%B8%89%E5%88%86%E7%90%83%E5%A4%A7%E8%B3%BD%2F%E6%8A%80%E5%B7%A7%E6%8C%91%E6%88%B0%E8%B3%BD%E5%90%8D%E5%96%AE">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alove1500274">搜尋看板內 love1500274 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">15</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644370205.A.FC0.html">[Live] 尼克 @ 金塊</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E5%B0%BC%E5%85%8B+%40+%E9%87%91%E5%A1%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644371560.A.613.html">[情報] TT預計會被溜馬買斷，他想去爭冠球隊</a>
# </div>
# <div class="meta">
# <div class="author">Wojnarowski</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+TT%E9%A0%90%E8%A8%88%E6%9C%83%E8%A2%AB%E6%BA%9C%E9%A6%AC%E8%B2%B7%E6%96%B7%EF%BC%8C%E4%BB%96%E6%83%B3%E5%8E%BB%E7%88%AD%E5%86%A0%E7%90%83%E9%9A%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AWojnarowski">搜尋看板內 Wojnarowski 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">73</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644373474.A.8A4.html">[BOX ] Suns 114:109 Sixers 數據</a>
# </div>
# <div class="meta">
# <div class="author">Rambo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Suns+114%3A109+Sixers+%E6%95%B8%E6%93%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ARambo">搜尋看板內 Rambo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644373803.A.408.html">[Live] 公鹿 @ 湖人</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E5%85%AC%E9%B9%BF+%40+%E6%B9%96%E4%BA%BA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644373806.A.2A1.html">[Live] 魔術 @ 拓荒者</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E9%AD%94%E8%A1%93+%40+%E6%8B%93%E8%8D%92%E8%80%85">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">9</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644373895.A.476.html">[Live] 灰狼 @ 國王</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BLive%5D+%E7%81%B0%E7%8B%BC+%40+%E5%9C%8B%E7%8E%8B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">60</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644374559.A.667.html">Re: [情報] 溜馬國王交易</a>
# </div>
# <div class="meta">
# <div class="author">Fantasy7th</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E6%BA%9C%E9%A6%AC%E5%9C%8B%E7%8E%8B%E4%BA%A4%E6%98%93">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AFantasy7th">搜尋看板內 Fantasy7th 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">93</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644374583.A.72B.html">[BOX ] Celtics 126:91 Nets 數據</a>
# </div>
# <div class="meta">
# <div class="author">Rambo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Celtics+126%3A91+Nets+%E6%95%B8%E6%93%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ARambo">搜尋看板內 Rambo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644374963.A.688.html">[BOX ] Pacers 112:133 Hawks 數據</a>
# </div>
# <div class="meta">
# <div class="author">Rambo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Pacers+112%3A133+Hawks+%E6%95%B8%E6%93%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ARambo">搜尋看板內 Rambo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">28</span></div>
# <div class="title">
#
# 				(本文已被刪除) [beckseaton]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 2/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1637555315.A.C34.html">[公告] 板規v9.0</a>
# </div>
# <div class="meta">
# <div class="author">pneumo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8Fv9.0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Apneumo">搜尋看板內 pneumo 的文章</a></div>
# </div>
# </div>
# <div class="date">11/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">8</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1643351103.A.0FF.html">[情報] SEASON Schedule February 21–22</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+SEASON+Schedule+February+21%E2%80%9322">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 1/28</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">12</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644239031.A.F2C.html">[情報] ★今日排名(2022.02.07)★</a>
# </div>
# <div class="meta">
# <div class="author">Rambo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E2%98%85%E4%BB%8A%E6%97%A5%E6%8E%92%E5%90%8D%282022.02.07%29%E2%98%85">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ARambo">搜尋看板內 Rambo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/07</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">16</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1644298563.A.614.html">[情報] NBA Standings (Feb. 07 &amp; 08, 2022)</a>
# </div>
# <div class="meta">
# <div class="author">guardyo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA+Standings+%28Feb.+07+%26+08%2C+2022%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aguardyo">搜尋看板內 guardyo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/08</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %% [markdown]
# ### 文章標題

# %%
# 尋找 class="title" 的 div 標籤
titles = soup.find('div', class_='title')
print('標題文字：', titles.a.string)
# Out:
# 標題文字： [Live] 青賽 @ 籃網

# %%
# 尋找所有 class="title" 的 div 標籤
titles = soup.find_all('div', class_='title')
for title in titles:
    print(title.a.string)
# Out:
# [Live] 青賽 @ 籃網
# Re: [討論] 拓荒者幹大事？
# [Live] 快艇 @ 灰熊
# [Live] 火箭 @ 鵜鶘
# [Live] 活塞 @ 獨行俠
# [情報] NBA史上前15名的教練
# [情報] 三分球大賽/技巧挑戰賽名單
# [Live] 尼克 @ 金塊
# [情報] TT預計會被溜馬買斷，他想去爭冠球隊
# [BOX ] Suns 114:109 Sixers 數據
# [Live] 公鹿 @ 湖人
# [Live] 魔術 @ 拓荒者
# [Live] 灰狼 @ 國王
# Re: [情報] 溜馬國王交易
# [BOX ] Celtics 126:91 Nets 數據
# [BOX ] Pacers 112:133 Hawks 數據
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-da6df2a705ed> in <module>
#       2 titles = soup.find_all('div', class_='title')
#       3 for title in titles:
# ----> 4     print(title.a.string)
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %% [markdown]
# ### test

# %%
soup.find('a', class_='board').text.lstrip('看板 ')
# Out:
# 'NBA'

# %%
# 爬取整篇文章
articles = soup.find_all('div', 'r-ent')

for article in articles:
    PTT_URL = "https://www.ptt.cc"
    page_div = soup.find('div', 'btn-group btn-group-paging')
    prev_page = page_div.find_all('a')[1]['href']  # 上頁
    latest_page = page_div.find_all('a')[3]['href']  # 最新
    
    today = dt.datetime.today().date().strftime('%m/%d').lstrip('0')
    date = article.find('div', 'date').text.strip()  # strip(): 去除字串頭尾的空格
    
    if date == today:
        if article.find('div', 'title').a == None:
            print(None)
        else:
            print(article.find('div', 'title').a.text)
    
    r = requests.get(PTT_URL + prev_page)
    soup = BeautifulSoup(r.text, "html.parser")
# Out:
# [新聞] 衛少陷生涯最大低潮　帕金斯：信心已經
# [花邊] 教練評價不夠性感，Jokic：他沒有說謊
# [新聞] 讚英格倫進攻高水準 鵜鶘主帥:天空才是極
# [情報] NBA Standings (Jan. 14, 2022)

# %%
single_article = soup.find_all('div', 'r-ent')[2]

# 需求資訊
title = single_article.find('div', 'title').a.text  # 標題
push_count = single_article.find('div', 'nrec').text  # 推文數 (str)
author = single_article.find('div', 'author').text  # author
date = single_article.find('div', 'date').text  # Date (str)
href = single_article.find('a')['href']  # URL = https://www.ptt.cc + href
board = soup.find('a', 'board').text.lstrip('看板 ')

# 頁面操作
page_div = soup.find('div', 'btn-group btn-group-paging')
prev_page = page_div.find_all('a')[1]['href']  # 上頁
latest_page = page_div.find_all('a')[3]['href']  # 最新
board
# Out:
# 'NBA'

# %%
date = single_article.find('div', 'date').text
dt.datetime.today().date().strftime('%m/%d').lstrip('0') == date.strip()
dt.datetime.today().date().strftime('%m/%d').lstrip('0')
# Out:
# '1/14'

# %%
page_div = soup.find('div', 'btn-group btn-group-paging')
page_div.find_all('a')[1]['href']
# Out:
# '/bbs/NBA/index6508.html'

# %% [markdown]
# ## modules
# > **爬取資訊**
#     >- 發文日期
#     >- 看板
#     >- 文章標題
#     >- 作者
#     >- 文章連結
#     >- 推文數
#     >- ~~推文內容~~
#
# > **Functions**
# >- **get_webPage (url)**
#     - 功能：取得網頁原始碼。
#     - Return：網頁原始碼。
#     - 參數
#         - url：欲爬取的 PTT 看板網址。
# >- **get_singlePage_posts (page)**
#     - 功能：取得單一頁面所有推文。
#     - Return：單一頁面所有推文（dict 格式）、上一頁 url。
#     - 參數
#         - page：get_webPage (url) return 的資料。
# >- **get_ptt_posts (url, return_pages)**
#     - 功能：爬取 PTT 指定看板推文。
#     - Return：DataFrame 格式資料。
#     - 參數
#         - url：欲爬取的 PTT 看板網址。
#         - return_pages：欲往回爬取幾頁的資料。（default = 0，表示僅爬取最新頁面資料）

# %%
def get_webPage(url):
    r = requests.get(url=url, cookies={'over18': '1'})  # cookies：有些看板會擋是否已滿18歲
    if r.status_code != 200:
        print('URL 無效，status code = ', r.status_code)
    else:
        return r.text
    
def get_singlePage_posts(page):
    # parse
    soup = BeautifulSoup(page, "html.parser")
    divs = soup.find_all('div', class_='r-ent')
    
    # 頁面資訊
    PTT_URL = "https://www.ptt.cc"
    board = soup.find('a', 'board').text.lstrip('看板 ')  # 看板
    
    page_div = soup.find('div', 'btn-group btn-group-paging')  # 控制頁面區塊
    prev_page_url = PTT_URL + page_div.find_all('a')[1]['href']  # 上頁
#     latest_page_url = PTT_URL + page_div.find_all('a')[3]['href']  # 最新
    
    # 日期
    today = dt.datetime.today().date().strftime('%m/%d').lstrip('0')
    
    # 需求欄位
    dates=[]
    titles=[]
    push_counts=[]
    authors=[]
    hrefs=[]
    
    # 最新頁面
    for article in divs:
        date = article.find('div', 'date').text.strip()  # strip(): 去除字串頭尾的空格
        
        # 篩選當日文章
#         if date == today:

        # 排除已刪除貼文
        if article.find('div', 'title').a == None:
            continue
        else:
            # 需求資訊
            title = article.find('div', 'title').a.text  # 標題
            push_count = article.find('div', 'nrec').text  # 推文數 (str)
            author = article.find('div', 'author').text  # author
            href = PTT_URL + article.find('a')['href']  # URL = https://www.ptt.cc + href

            dates.append(date)
            titles.append(title)
            push_counts.append(push_count)
            authors.append(author)
            hrefs.append(href)
#         else:
#             continue
    
    # return 最新頁面的推文
    posts = {'date': dates, 
            'board': board, 
            'title': titles, 
            'push_count': push_counts, 
            'author': authors, 
            'href': hrefs}
    
    return posts, prev_page_url

def get_ptt_posts(url, return_pages=0):
    # 先爬取最新頁面的所有推文
    all_posts = []
    page = get_webPage(url)
    posts, prev_page_url = get_singlePage_posts(page)
    all_posts.append(posts)

    # 再往前 return_pages 頁
    count = 0
    while count < return_pages:
        page = get_webPage(prev_page_url)
        posts, prev_page_url = get_singlePage_posts(page)
        all_posts.append(posts)
        count += 1
    
    # 轉換為 DataFrame
    df = pd.DataFrame()
    for post in all_posts:
        df = pd.concat([df, pd.DataFrame(post)])
        
    df.reset_index(inplace=True, drop=True)
    return df

# %% [markdown]
# ## 主程式

# %% [markdown]
# ### 使用 function

# %%
get_ptt_posts(url="https://www.ptt.cc/bbs/NBA/index.html")
# Out:
#     date board                                    title push_count  \
# 0   2/09   NBA                          [情報] 紐約疫苗規定或將取消         56
# 1   2/09   NBA             [花邊] NAW和Josh Hart被交易後坐在場邊看球         16
# 2   2/09   NBA       [BOX ] Pistons 86:116 Mavericks 數據         21
# 3   2/09   NBA                Fw: [情報] 高雄鋼鐵人新洋將 Bennett          爆
# 4  11/22   NBA                              [公告] 板規v9.0          1
# 5   1/28   NBA      [情報] SEASON Schedule February 21–22          8
# 6   2/07   NBA                  [情報] ★今日排名(2022.02.07)★         12
# 7   2/08   NBA  [情報] NBA Standings (Feb. 07 & 08, 2022)         16
#
#         author                                                href
# 0       FengQQ  https://www.ptt.cc/bbs/NBA/M.1644378138.A.1DE.html
# 1  willy911006  https://www.ptt.cc/bbs/NBA/M.1644378329.A.AD6.html
# 2        Rambo  https://www.ptt.cc/bbs/NBA/M.1644378557.A.75C.html
# 3   asdfgh0920  https://www.ptt.cc/bbs/NBA/M.1644379310.A.39B.html
# 4       pneumo  https://www.ptt.cc/bbs/NBA/M.1637555315.A.C34.html
# 5       laptic  https://www.ptt.cc/bbs/NBA/M.1643351103.A.0FF.html
# 6        Rambo  https://www.ptt.cc/bbs/NBA/M.1644239031.A.F2C.html
# 7      guardyo  https://www.ptt.cc/bbs/NBA/M.1644298563.A.614.html

# %% [markdown]
# ### 沒使用 function

# %%
all_posts = []
page = get_webPage("https://www.ptt.cc/bbs/NBA/index.html")
posts, prev_page_url = get_posts(page)
all_posts.append(posts)

# 往前 5 頁
count = 0
while count < 5:
    page = get_webPage(prev_page_url)
    posts, prev_page_url = get_posts(page)
    all_posts.append(posts)
    count += 1

df = pd.DataFrame()
for post in all_posts:
    df = pd.concat([df, pd.DataFrame(post)])

# %%
# df.reset_index(inplace=True, drop=True)
df
# Out:
#      date board                               title push_count       author  \
# 0    2/09   NBA                     [情報] 紐約疫苗規定或將取消         52       FengQQ
# 1    2/09   NBA        [花邊] NAW和Josh Hart被交易後坐在場邊看球         14  willy911006
# 2    2/09   NBA  [BOX ] Pistons 86:116 Mavericks 數據         19        Rambo
# 3    2/09   NBA           Fw: [情報] 高雄鋼鐵人新洋將 Bennett         60   asdfgh0920
# 4   11/22   NBA                         [公告] 板規v9.0          1       pneumo
# ..    ...   ...                                 ...        ...          ...
# 14   2/08   NBA                      [Live] 太陽 @ 公牛          爆       laptic
# 15   2/08   NBA           [外絮] LBJ談交易截止日：如果有機會變得更好沒         96     arod1414
# 16   2/08   NBA            [新聞] 讚德羅展腳步動作 安比德：想起了布萊恩         36   sodistrues
# 17   2/08   NBA          [情報] 黃蜂Gordon Hayward左腳踝扭傷         81        sezna
# 18   2/08   NBA                      [Live] 尼克 @ 爵士         23       laptic
#
#                                                   href
# 0   https://www.ptt.cc/bbs/NBA/M.1644378138.A.1DE.html
# 1   https://www.ptt.cc/bbs/NBA/M.1644378329.A.AD6.html
# 2   https://www.ptt.cc/bbs/NBA/M.1644378557.A.75C.html
# 3   https://www.ptt.cc/bbs/NBA/M.1644379310.A.39B.html
# 4   https://www.ptt.cc/bbs/NBA/M.1637555315.A.C34.html
# ..                                                 ...
# 14  https://www.ptt.cc/bbs/NBA/M.1644280420.A.374.html
# 15  https://www.ptt.cc/bbs/NBA/M.1644280513.A.0BD.html
# 16  https://www.ptt.cc/bbs/NBA/M.1644280604.A.5F3.html
# 17  https://www.ptt.cc/bbs/NBA/M.1644284093.A.05C.html
# 18  https://www.ptt.cc/bbs/NBA/M.1644284375.A.5F2.html
#
# [100 rows x 6 columns]

# %% [markdown]
# # 開爬

# %% [markdown]
# ## NBA

# %%
url = 'https://www.ptt.cc/bbs/NBA/index.html'
nba = get_ptt_posts(url, 3)
nba
# Out:
#      date board                               title push_count       author  \
# 0    2/09   NBA                     [情報] 紐約疫苗規定或將取消         56       FengQQ
# 1    2/09   NBA        [花邊] NAW和Josh Hart被交易後坐在場邊看球         17  willy911006
# 2    2/09   NBA  [BOX ] Pistons 86:116 Mavericks 數據         21        Rambo
# 3    2/09   NBA           Fw: [情報] 高雄鋼鐵人新洋將 Bennett          爆   asdfgh0920
# 4   11/22   NBA                         [公告] 板規v9.0          1       pneumo
# ..    ...   ...                                 ...        ...          ...
# 57   2/08   NBA                   Re: [討論] 西河其實蠻冤枉的                  AOB123
# 58   2/08   NBA                   Re: [討論] 西河其實蠻冤枉的         25       bangch
# 59   2/08   NBA           [花邊] DJM 七年前的推特說總有一天要進明星賽         64        Petyr
# 60   2/08   NBA     [情報] 湖人隊向塞爾提克洽談 Josh Richardson         51   thnlkj0665
# 61   2/08   NBA                 [情報] 入選全明星賽10次以上的球員         33   crownschou
#
#                                                   href
# 0   https://www.ptt.cc/bbs/NBA/M.1644378138.A.1DE.html
# 1   https://www.ptt.cc/bbs/NBA/M.1644378329.A.AD6.html
# 2   https://www.ptt.cc/bbs/NBA/M.1644378557.A.75C.html
# 3   https://www.ptt.cc/bbs/NBA/M.1644379310.A.39B.html
# 4   https://www.ptt.cc/bbs/NBA/M.1637555315.A.C34.html
# ..                                                 ...
# 57  https://www.ptt.cc/bbs/NBA/M.1644326621.A.4CE.html
# 58  https://www.ptt.cc/bbs/NBA/M.1644327291.A.C2D.html
# 59  https://www.ptt.cc/bbs/NBA/M.1644328051.A.F2C.html
# 60  https://www.ptt.cc/bbs/NBA/M.1644330386.A.8B6.html
# 61  https://www.ptt.cc/bbs/NBA/M.1644330892.A.F5C.html
#
# [62 rows x 6 columns]

# %% [markdown]
# ## 八卦版

# %%
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
gossiping = get_ptt_posts(url, 3)
gossiping
# Out:
#     date      board                       title push_count      author  \
# 0   2/09  Gossiping           [協尋] 台中貴賓狗協尋賞金60萬                jhct110
# 1   2/09  Gossiping      Re: [問卦] 買15元麥香的是不是傻子？               chen0625
# 2   2/09  Gossiping      [問卦] 你各位電視現在是Mod還是第四台？               w1230319
# 3   2/09  Gossiping           [問卦] 讓外送員等多久是合理的？               acln0816
# 4   2/09  Gossiping  Re: [新聞] 高雄民族路機車速限40 引鄉民論戰                     A6
# ..   ...        ...                         ...        ...         ...
# 64  2/09  Gossiping         [問卦] 大樓蓋一堆公設要幹嘛又用不到         10   cj4385283
# 65  2/09  Gossiping    [新聞] 陳時中鬆口不排斥參選 蔣萬安：現在不適         12       runa2
# 66  2/09  Gossiping             [問卦] 核四弊案為什麼沒事?               cattgirl
# 67  2/09  Gossiping         [爆卦] 李玟誼冬奧高山滑雪晉級決賽!         21      Borges
# 68  2/09  Gossiping         [問卦] 記者什麼時候可以不抄PTT？         20  a1b2c3d4e5
#
#                                                         href
# 0   https://www.ptt.cc/bbs/Gossiping/M.1644380284.A.D94.html
# 1   https://www.ptt.cc/bbs/Gossiping/M.1644380292.A.214.html
# 2   https://www.ptt.cc/bbs/Gossiping/M.1644380323.A.DEC.html
# 3   https://www.ptt.cc/bbs/Gossiping/M.1644380335.A.C2D.html
# 4   https://www.ptt.cc/bbs/Gossiping/M.1644380344.A.8CA.html
# ..                                                       ...
# 64  https://www.ptt.cc/bbs/Gossiping/M.1644379114.A.541.html
# 65  https://www.ptt.cc/bbs/Gossiping/M.1644379154.A.8F9.html
# 66  https://www.ptt.cc/bbs/Gossiping/M.1644379170.A.5DE.html
# 67  https://www.ptt.cc/bbs/Gossiping/M.1644379226.A.BD5.html
# 68  https://www.ptt.cc/bbs/Gossiping/M.1644379227.A.C26.html
#
# [69 rows x 6 columns]

# %% [markdown]
# ## Stock

# %%
url = 'https://www.ptt.cc/bbs/Stock/index.html'
stock = get_ptt_posts(url, 3)
stock
# Out:
#     date  board                       title push_count       author  \
# 0   2/09  Stock     [新聞] 世貿組織認定美對韓加徵洗衣機進口關稅         31  CavendishJr
# 1   2/09  Stock        Re: [新聞] 美管制陸企 砍向面板業         19       winall
# 2   2/09  Stock         [閒聊] 2022/02/09盤中閒聊          爆  justforsing
# 3   2/09  Stock   [新聞] 產業分析》大摩：IT面板帶來不確定性 中         32   rubberking
# 4   2/09  Stock  [新聞] 歡迎台積電合作！ 歐盟斥資1.37兆堆晶片         57  s3z15a3z15a
# ..   ...    ...                         ...        ...          ...
# 61  2/08  Stock         [情報] 富旺處分陽明普通股股票之公告         25  village0817
# 62  2/08  Stock            [情報] 6412群電 1月營收          5  nodnarb1027
# 63  2/08  Stock        [情報] 4958 臻鼎-KY 1月營收         26  nodnarb1027
# 64  2/08  Stock   Re: [新聞] 瑞幸咖啡：已繳納1.8億美元罰款          8    danny7373
# 65  2/08  Stock     [新聞] 航運股「還不能追」！分析師提醒：已逼         88     jason748
#
#                                                     href
# 0   https://www.ptt.cc/bbs/Stock/M.1644365672.A.1A5.html
# 1   https://www.ptt.cc/bbs/Stock/M.1644365818.A.99C.html
# 2   https://www.ptt.cc/bbs/Stock/M.1644366602.A.865.html
# 3   https://www.ptt.cc/bbs/Stock/M.1644370796.A.AA4.html
# 4   https://www.ptt.cc/bbs/Stock/M.1644375753.A.500.html
# ..                                                   ...
# 61  https://www.ptt.cc/bbs/Stock/M.1644313553.A.82A.html
# 62  https://www.ptt.cc/bbs/Stock/M.1644313904.A.638.html
# 63  https://www.ptt.cc/bbs/Stock/M.1644314409.A.F77.html
# 64  https://www.ptt.cc/bbs/Stock/M.1644314633.A.6F5.html
# 65  https://www.ptt.cc/bbs/Stock/M.1644315035.A.059.html
#
# [66 rows x 6 columns]

# %% [markdown]
# ## money

# %%
url = 'https://www.ptt.cc/bbs/money/index.html'
money = get_ptt_posts(url, 3)
money
# Out:
#     date  board                            title push_count        author  \
# 0   6/23  money  Fw: [心得] 2609陽明目標價之我見-20年歷史數據分析          5       az61007
# 1   7/15  money         [新聞] 女股神：比特幣環保擔憂只是一時 長期仍                 hateOnas
# 2   7/26  money              Fw: [請益] 從工作經驗推論航運業                 hateOnas
# 3   8/02  money          [其他] money and currency                 hsiliang
# 4   8/03  money                Fw: [公告] 8/8 停機公告          2       az61007
# ..   ...    ...                              ...        ...           ...
# 72  4/11  money           Re: [問題] 想知道特地過來酸的心態是？         15     crazybaby
# 73  4/12  money      [公告] drgon違反群組規十一依臨時板規水桶30天         45         IanLi
# 74  4/12  money             Re: [建議] 趕快離開這個板來CFP          6  walter741225
# 75  4/12  money  Re: [公告] drgon違反群組規十一依臨時板規水桶30天                  st90513
# 76  4/12  money  Re: [公告] drgon違反群組規十一依臨時板規水桶30天         19      D600dust
#
#                                                     href
# 0   https://www.ptt.cc/bbs/money/M.1624450998.A.24E.html
# 1   https://www.ptt.cc/bbs/money/M.1626329131.A.EF3.html
# 2   https://www.ptt.cc/bbs/money/M.1627267068.A.D4A.html
# 3   https://www.ptt.cc/bbs/money/M.1627918377.A.8C1.html
# 4   https://www.ptt.cc/bbs/money/M.1627982048.A.856.html
# ..                                                   ...
# 72  https://www.ptt.cc/bbs/money/M.1618154927.A.3CC.html
# 73  https://www.ptt.cc/bbs/money/M.1618179846.A.90F.html
# 74  https://www.ptt.cc/bbs/money/M.1618182368.A.AE7.html
# 75  https://www.ptt.cc/bbs/money/M.1618184502.A.542.html
# 76  https://www.ptt.cc/bbs/money/M.1618185547.A.9A4.html
#
# [77 rows x 6 columns]

# %%
money.query('date == "2/09"')
# Out:
#     date  board             title push_count author  \
# 14  2/09  money  [標的]  網龍 3083 短多         42  drgon
#
#                                                     href
# 14  https://www.ptt.cc/bbs/money/M.1644370114.A.54E.html

# %% [markdown]
# # 串接 Google sheet
#
# > Ref
# >- [[Python爬蟲教學]解析如何串接Google Sheet試算表寫入爬取的資料](https://www.learncodewithmike.com/2020/08/python-write-to-google-sheet.html)
# >- [Python 讀寫 Google Sheets 教學](https://hackmd.io/@Yun-Cheng/GoogleSheets)

# %% [markdown]
# ## gsheet 認證

# %%
gc = pygsheets.authorize(service_account_file=s.GSHEETS_PYTHON_CONNECT_PATH)

# Google sheet URL
survey_url = 'https://docs.google.com/spreadsheets/d/1kI3AECFBEBFbOo4QxL1SCyA8ekcxROLkkO_5ocXQatU/edit#gid=0'

sh = gc.open_by_url(survey_url)

# %% [markdown]
# ## 讀取目標工作表

# %%
ws_NBA = sh.worksheet_by_title('NBA')

# %%
ws_Gossiping = sh.worksheet_by_title('Gossiping')

# %% [markdown]
# ## 寫入工作表
# - [set_dataframe()](https://pygsheets.readthedocs.io/en/stable/worksheet.html#pygsheets.Worksheet.set_dataframe)

# %%
ws_NBA.set_dataframe(nba, start='B2')

# %%
ws_Gossiping.set_dataframe(gossiping, start='B2')

# %% [markdown]
# ## 讀取目標工作表後，將工作表轉換為 DataFrame
# - [set_as_df()](https://pygsheets.readthedocs.io/en/stable/worksheet.html#pygsheets.Worksheet.get_as_df)

# %%
nba_gsheet = ws_NBA.get_as_df(start='B2')
nba_gsheet
# Out:
#      date board                               title push_count       author  \
# 0   02/09   NBA                     [情報] 紐約疫苗規定或將取消         56       FengQQ
# 1   02/09   NBA        [花邊] NAW和Josh Hart被交易後坐在場邊看球         17  willy911006
# 2   02/09   NBA  [BOX ] Pistons 86:116 Mavericks 數據         21        Rambo
# 3   02/09   NBA           Fw: [情報] 高雄鋼鐵人新洋將 Bennett          爆   asdfgh0920
# 4   11/22   NBA                         [公告] 板規v9.0          1       pneumo
# ..    ...   ...                                 ...        ...          ...
# 57  02/08   NBA                   Re: [討論] 西河其實蠻冤枉的                  AOB123
# 58  02/08   NBA                   Re: [討論] 西河其實蠻冤枉的         25       bangch
# 59  02/08   NBA           [花邊] DJM 七年前的推特說總有一天要進明星賽         64        Petyr
# 60  02/08   NBA     [情報] 湖人隊向塞爾提克洽談 Josh Richardson         51   thnlkj0665
# 61  02/08   NBA                 [情報] 入選全明星賽10次以上的球員         33   crownschou
#
#                                                   href
# 0   https://www.ptt.cc/bbs/NBA/M.1644378138.A.1DE.html
# 1   https://www.ptt.cc/bbs/NBA/M.1644378329.A.AD6.html
# 2   https://www.ptt.cc/bbs/NBA/M.1644378557.A.75C.html
# 3   https://www.ptt.cc/bbs/NBA/M.1644379310.A.39B.html
# 4   https://www.ptt.cc/bbs/NBA/M.1637555315.A.C34.html
# ..                                                 ...
# 57  https://www.ptt.cc/bbs/NBA/M.1644326621.A.4CE.html
# 58  https://www.ptt.cc/bbs/NBA/M.1644327291.A.C2D.html
# 59  https://www.ptt.cc/bbs/NBA/M.1644328051.A.F2C.html
# 60  https://www.ptt.cc/bbs/NBA/M.1644330386.A.8B6.html
# 61  https://www.ptt.cc/bbs/NBA/M.1644330892.A.F5C.html
#
# [62 rows x 6 columns]

# %%
gossiping_gsheet = ws_Gossiping.get_as_df(start='B2')
gossiping_gsheet
# Out:
#      date      board                       title push_count      author  \
# 0   02/09  Gossiping           [協尋] 台中貴賓狗協尋賞金60萬                jhct110
# 1   02/09  Gossiping      Re: [問卦] 買15元麥香的是不是傻子？               chen0625
# 2   02/09  Gossiping      [問卦] 你各位電視現在是Mod還是第四台？               w1230319
# 3   02/09  Gossiping           [問卦] 讓外送員等多久是合理的？               acln0816
# 4   02/09  Gossiping  Re: [新聞] 高雄民族路機車速限40 引鄉民論戰                     A6
# ..    ...        ...                         ...        ...         ...
# 64  02/09  Gossiping         [問卦] 大樓蓋一堆公設要幹嘛又用不到         10   cj4385283
# 65  02/09  Gossiping    [新聞] 陳時中鬆口不排斥參選 蔣萬安：現在不適         12       runa2
# 66  02/09  Gossiping             [問卦] 核四弊案為什麼沒事?               cattgirl
# 67  02/09  Gossiping         [爆卦] 李玟誼冬奧高山滑雪晉級決賽!         21      Borges
# 68  02/09  Gossiping         [問卦] 記者什麼時候可以不抄PTT？         20  a1b2c3d4e5
#
#                                                         href
# 0   https://www.ptt.cc/bbs/Gossiping/M.1644380284.A.D94.html
# 1   https://www.ptt.cc/bbs/Gossiping/M.1644380292.A.214.html
# 2   https://www.ptt.cc/bbs/Gossiping/M.1644380323.A.DEC.html
# 3   https://www.ptt.cc/bbs/Gossiping/M.1644380335.A.C2D.html
# 4   https://www.ptt.cc/bbs/Gossiping/M.1644380344.A.8CA.html
# ..                                                       ...
# 64  https://www.ptt.cc/bbs/Gossiping/M.1644379114.A.541.html
# 65  https://www.ptt.cc/bbs/Gossiping/M.1644379154.A.8F9.html
# 66  https://www.ptt.cc/bbs/Gossiping/M.1644379170.A.5DE.html
# 67  https://www.ptt.cc/bbs/Gossiping/M.1644379226.A.BD5.html
# 68  https://www.ptt.cc/bbs/Gossiping/M.1644379227.A.C26.html
#
# [69 rows x 6 columns]
