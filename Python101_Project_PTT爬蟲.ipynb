# %% [markdown]
# # Tools

# %%
import requests
from bs4 import BeautifulSoup
import datetime as dt
import pandas as pd

pd.options.display.max_columns=None
pd.set_option('max_colwidth', None)  # 設定 value 顯示長度

# %% [markdown]
# # 開爬
# > **爬取每日熱門爬取每日熱門文章。**
#
# > **爬取資訊**
#     >- 看板
#     >- 文章標題
#     >- 作者
#     >- 發文時間
#     >- 文章連結
#     >- 推文數
#     >- 文章內容
#     >- 推文內容
#
# > **資訊位置**
#     >- 'div', 'r-ent'
#     - 文章標題
#
# >- 流程
#     1. 輸入URL，獲取網頁原始碼
#     2. 透過 BeautifulSoup 解析 HTML 格式文件
#     3. 從最新頁面開始爬取
#         - 設定爬取條件
#         - 將需求資訊以 dict 儲存
#         - return 上一頁 URL
#     4. 往上一頁爬取（設定爬取條件）

# %%
url = "https://www.ptt.cc/bbs/NBA/index.html"

### 1. 取得 response
r = requests.get(url)  # cookies={'over18': '1'}

### 2. 透過 parser 轉換成 BeautifulSoup 比較好處理的格式（以 BeautifulSoup 解析 HTML 格式文件）
"""
    - soup是獲得的文件物件, html.parser是支援的parser.
    - 關於parser, 比較常見的parser有這些：html.parser / html5lib / lxml。
    
    - BeautifulSoup 會根據指定的 parser 把文件轉換成一個複雜的樹形結構，每個節點都是 Python 物件。
        - 所有物件大致上可歸類為4種:
            - BeautifulSoup: 表示一個文件的所有內容.
            - Tag: 基本上就是HTML裡的各種tag(div, p, etc...). 每個tag有兩個重要的屬性: 
                - name: 即tag的名字或著tag本身的name.
                - attrs: 通常指一個tag的class(常用).
            - NavigableString: 取得tag內的文字, 如: soup.p.string
            - Comment: 此物件是一個特殊的NavigableString物件, 其輸出的內容不包含註解符號.
"""
soup = BeautifulSoup(r.text, "html.parser")

### 3. Results
print('status_code: ', r.status_code)
# print('未解析資料: ', r.text)
print('解析後資料', soup)
# Out:
# status_code:  200
# 解析後資料 <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/NBA/index.html">看板</a>
# <a class="btn" href="/man/NBA/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/NBA/index6514.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/NBA/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">72</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1642142004.A.A9E.html">[新聞] 衛少陷生涯最大低潮　帕金斯：信心已經</a>
# </div>
# <div class="meta">
# <div class="author">arod1414</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%A1%9B%E5%B0%91%E9%99%B7%E7%94%9F%E6%B6%AF%E6%9C%80%E5%A4%A7%E4%BD%8E%E6%BD%AE%E3%80%80%E5%B8%95%E9%87%91%E6%96%AF%EF%BC%9A%E4%BF%A1%E5%BF%83%E5%B7%B2%E7%B6%93">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aarod1414">搜尋看板內 arod1414 的文章</a></div>
# </div>
# </div>
# <div class="date"> 1/14</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">21</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1642145052.A.877.html">[花邊] 教練評價不夠性感，Jokic：他沒有說謊</a>
# </div>
# <div class="meta">
# <div class="author">LABOYS</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E6%95%99%E7%B7%B4%E8%A9%95%E5%83%B9%E4%B8%8D%E5%A4%A0%E6%80%A7%E6%84%9F%EF%BC%8CJokic%EF%BC%9A%E4%BB%96%E6%B2%92%E6%9C%89%E8%AA%AA%E8%AC%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3ALABOYS">搜尋看板內 LABOYS 的文章</a></div>
# </div>
# </div>
# <div class="date"> 1/14</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">17</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1642145412.A.2C1.html">[新聞] 讚英格倫進攻高水準 鵜鶘主帥:天空才是極</a>
# </div>
# <div class="meta">
# <div class="author">thnlkj0665</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%AE%9A%E8%8B%B1%E6%A0%BC%E5%80%AB%E9%80%B2%E6%94%BB%E9%AB%98%E6%B0%B4%E6%BA%96+%E9%B5%9C%E9%B6%98%E4%B8%BB%E5%B8%A5%3A%E5%A4%A9%E7%A9%BA%E6%89%8D%E6%98%AF%E6%A5%B5">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Athnlkj0665">搜尋看板內 thnlkj0665 的文章</a></div>
# </div>
# </div>
# <div class="date"> 1/14</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1637555315.A.C34.html">[公告] 板規v9.0</a>
# </div>
# <div class="meta">
# <div class="author">pneumo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8Fv9.0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Apneumo">搜尋看板內 pneumo 的文章</a></div>
# </div>
# </div>
# <div class="date">11/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">8</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1640417498.A.092.html">[情報] SEASON Schedule January 21–22</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+SEASON+Schedule+January+21%E2%80%9322">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date">12/25</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">13</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1642138204.A.239.html">[情報] NBA Standings (Jan. 14, 2022)</a>
# </div>
# <div class="meta">
# <div class="author">guardyo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+NBA+Standings+%28Jan.+14%2C+2022%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aguardyo">搜尋看板內 guardyo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 1/14</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %% [markdown]
# ## 文章標題

# %%
# 尋找 class="title" 的 div 標籤
titles = soup.find('div', class_='title')
print('標題文字：', titles.a.string)
# Out:
# 標題文字： [新聞] 衛少陷生涯最大低潮　帕金斯：信心已經

# %%
# 尋找所有 class="title" 的 div 標籤
titles = soup.find_all('div', class_='title')
for title in titles:
    print(title.a.string)
# Out:
# [新聞] 衛少陷生涯最大低潮　帕金斯：信心已經
# [花邊] 教練評價不夠性感，Jokic：他沒有說謊
# [新聞] 讚英格倫進攻高水準 鵜鶘主帥:天空才是極
# [公告] 板規v9.0
# [情報] SEASON Schedule January 21–22
# [情報] NBA Standings (Jan. 14, 2022)

# %% [markdown]
# ## test

# %%
# 爬取整篇文章
articles = soup.find_all('div', 'r-ent')

for article in articles:
    PTT_URL = "https://www.ptt.cc"
    page_div = soup.find('div', 'btn-group btn-group-paging')
    prev_page = page_div.find_all('a')[1]['href']  # 上頁
    latest_page = page_div.find_all('a')[3]['href']  # 最新
    
    today = dt.datetime.today().date().strftime('%m/%d').lstrip('0')
    date = article.find('div', 'date').text.strip()  # strip(): 去除字串頭尾的空格
    
    if date == today:
        if article.find('div', 'title').a == None:
            print(None)
        else:
            print(article.find('div', 'title').a.text)
    
    r = requests.get(PTT_URL + prev_page)
    soup = BeautifulSoup(r.text, "html.parser")
# Out:
# [新聞] 衛少陷生涯最大低潮　帕金斯：信心已經
# [花邊] 教練評價不夠性感，Jokic：他沒有說謊
# [新聞] 讚英格倫進攻高水準 鵜鶘主帥:天空才是極
# [情報] NBA Standings (Jan. 14, 2022)

# %%
single_article = soup.find_all('div', 'r-ent')[2]

# 需求資訊
title = single_article.find('div', 'title').a.text  # 標題
push_count = single_article.find('div', 'nrec').text  # 推文數 (str)
author = single_article.find('div', 'author').text  # author
date = single_article.find('div', 'date').text  # Date (str)
href = single_article.find('a')['href']  # URL = https://www.ptt.cc + href
board = soup.find('a', 'board').text.lstrip('看板 ')

# 頁面操作
page_div = soup.find('div', 'btn-group btn-group-paging')
prev_page = page_div.find_all('a')[1]['href']  # 上頁
latest_page = page_div.find_all('a')[3]['href']  # 最新
board
# Out:
# 'NBA'

# %%
date = single_article.find('div', 'date').text
dt.datetime.today().date().strftime('%m/%d').lstrip('0') == date.strip()
dt.datetime.today().date().strftime('%m/%d').lstrip('0')
# Out:
# '1/14'

# %% [markdown]
# ## modules
# > **爬取資訊**
#     >- 看板
#     >- 文章標題
#     >- 作者
#     >- 發文時間
#     >- 文章連結
#     >- 推文數
#     >- 文章內容
#     >- 推文內容

# %%
def get_webPage(url):
    r = requests.get(url=url, cookies={'over18': '1'})  # cookies：有些看板會擋是否已滿18歲
    if r.status_code != 200:
        print('URL 無效，status code = ', r.status_code)
    else:
        return r.text
    
def get_articles(page):
    # parse
    soup = BeautifulSoup(page, "html.parser")
    divs = soup.find_all('div', 'r-ent')
    
    # 頁面資訊
    PTT_URL = "https://www.ptt.cc"
    board = soup.find('a', 'board').text.lstrip('看板 ')
    page_div = soup.find('div', 'btn-group btn-group-paging')
    prev_page_url = PTT_URL + page_div.find_all('a')[1]['href']  # 上頁
#     latest_page_url = PTT_URL + page_div.find_all('a')[3]['href']  # 最新
    
    # 日期
    today = dt.datetime.today().date().strftime('%m/%d').lstrip('0')
    
    # 需求欄位
    titles=[]
    push_counts=[]
    authors=[]
    hrefs=[]
    
    # 最新頁面
    for article in divs:
        date = article.find('div', 'date').text.strip()  # strip(): 去除字串頭尾的空格
        
        # 篩選當日文章
        if date == today:
            # 排除已刪除貼文
            if article.find('div', 'title').a == None:
                continue
            else:
                # 需求資訊
                title = article.find('div', 'title').a.text  # 標題
                push_count = article.find('div', 'nrec').text  # 推文數 (str)
                author = article.find('div', 'author').text  # author
                href = PTT_URL + article.find('a')['href']  # URL = https://www.ptt.cc + href
                
                titles.append(title)
                push_counts.append(push_count)
                authors.append(author)
                hrefs.append(href)
        else:
            continue
    
    # 前一頁
    prev_page = get_webPage(prev_page_url)
        
    data = {'date': today, 
            'board': board, 
            'title': titles, 
            'push_count': push_counts, 
            'author': authors, 
            'href': hrefs}
    
    return data, prev_page_url

# %% [markdown]
# ## 主程式
# - 再包一層：get_ptt_data()

# %%
all_data = []
page = get_webPage("https://www.ptt.cc/bbs/NBA/index.html")
dict_data, prev_page_url = get_articles(page)
all_data.append(dict_data)

# 往前 5 頁
count = 0
while count < 5:
    page = get_webPage(prev_page_url)
    dict_data, prev_page_url = get_articles(page)
    all_data.append(dict_data)
    count += 1

df = pd.DataFrame()
for data in all_data:
    df = pd.concat([df, pd.DataFrame(data)])

# %%
df
# Out:
#     date board                                     title push_count  \
# 0   1/14   NBA                   [新聞] 衛少陷生涯最大低潮　帕金斯：信心已經         72
# 1   1/14   NBA                 [花邊] 教練評價不夠性感，Jokic：他沒有說謊         21
# 2   1/14   NBA                 [新聞] 讚英格倫進攻高水準 鵜鶘主帥:天空才是極         17
# 3   1/14   NBA        [情報] NBA Standings (Jan. 14, 2022)         13
# 0   1/14   NBA        [BOX ] Clippers 89:113 Pelicans 數據         16
# 1   1/14   NBA  [BOX ] Timberwolves 108:116 Grizzlies 數據         58
# 2   1/14   NBA                    [花邊] Bobby Portis 慶祝動作         52
# 3   1/14   NBA            [BOX ] Thunder 130:109 Nets 數據         78
# 4   1/14   NBA                [討論] Gobert跟Green的重要性被低估了嗎         51
# 5   1/14   NBA                   [情報] 湖人本季對戰超過五成勝率的球隊僅五勝         83
# 6   1/14   NBA             [外絮] Curry:雖然CP3至今無冠 但不影響他的偉大         67
# 7   1/14   NBA           Re: [花邊] 孩童拿敵隊球衣免費換Morant球衣+2張票         55
# 8   1/14   NBA                                 [公告]不罰*3          10
# 9   1/14   NBA                            [情報] 哈登賽後說他累壞了         27
# 10  1/14   NBA         [BOX ] Blazers 108:140 Nuggets 數據         24
# 11  1/14   NBA               Re: [情報] 湖人本季對戰超過五成勝率的球隊僅五勝         59
# 12  1/14   NBA                   [新聞]安戴托昆波大三元領軍 公鹿主場痛宰勇士         19
# 13  1/14   NBA        [情報] NBA Standings (Jan. 14, 2022)         20
# 14  1/14   NBA               [新聞] LHW-前NBA選秀榜眼騎車被撞成癱瘓　怕成         31
# 15  1/14   NBA                 [新聞] CCY-交易截止日將近！美媒曝勒夫不想再         19
# 16  1/14   NBA             [情報] Forbes 2021球隊市值及營收；爵士最賺錢         37
# 17  1/14   NBA                   [情報] NBA將停止每日COVID-19檢測          爆
# 18  1/14   NBA             [情報] Harden三分打鐵數追平Allen並列歷史第一         14
# 0   1/14   NBA                 [花邊] KD比賽中想偷偷跑上場換人被Nash拉住         47
# 1   1/14   NBA                 Re: [討論] Curry和KD哪個進攻比較難守         43
# 2   1/14   NBA                        [花邊] 金塊Bol Bol交易取消         16
# 3   1/14   NBA           Re: [花邊] Booker跟裁判抗議罰球時被暴龍的吉祥物干          8
# 4   1/14   NBA                          [花邊] 全明星第二階段票數公佈         78
# 5   1/14   NBA                   [情報] 聯盟禁止國王主場繼續頒發單場最冷球員         87
# 6   1/14   NBA                            [Live] 勇士 @ 公鹿          爆
# 7   1/14   NBA                            [Live] 快艇 @ 鵜鶘
# 8   1/14   NBA                            [Live] 灰狼 @ 灰熊         59
# 9   1/14   NBA                   [外絮] 龜龜：把批評視為讚美，如果受到關注表         97
# 10  1/14   NBA           [情報] 湖人正在評估DH,DAJ,Bazemore的交易價值          爆
# 11  1/14   NBA                            [Live] 雷霆 @ 籃網         64
# 12  1/14   NBA                       [花邊] 球迷拿Zion球衣換Ja球衣          爆
# 13  1/14   NBA                  [討論] 有底薪上車結果被當成籌碼去換人的例子嗎         37
# 14  1/14   NBA                           [Live] 拓荒者 @ 金塊          8
# 15  1/14   NBA           [BOX ] Warriors 99:118 Bucks 數據          爆
# 16  1/14   NBA                         [外絮] 尼克或許會在本季交易JR         31
# 0   1/14   NBA                 Re: [討論] Curry和KD哪個進攻比較難守         37
# 1   1/14   NBA                  [專欄] 新總仔哀鴻遍野 只有獨行俠基德笑得出來         15
# 2   1/14   NBA         [情報] Cam Reddish去尼克、Kevin Knox去老鷹          爆
#
#          author                                                href
# 0      arod1414  https://www.ptt.cc/bbs/NBA/M.1642142004.A.A9E.html
# 1        LABOYS  https://www.ptt.cc/bbs/NBA/M.1642145052.A.877.html
# 2    thnlkj0665  https://www.ptt.cc/bbs/NBA/M.1642145412.A.2C1.html
# 3       guardyo  https://www.ptt.cc/bbs/NBA/M.1642138204.A.239.html
# 0         Rambo  https://www.ptt.cc/bbs/NBA/M.1642130109.A.040.html
# 1         Rambo  https://www.ptt.cc/bbs/NBA/M.1642131342.A.E86.html
# 2   hijacknokia  https://www.ptt.cc/bbs/NBA/M.1642131497.A.1AF.html
# 3         Rambo  https://www.ptt.cc/bbs/NBA/M.1642132256.A.CE8.html
# 4      k7202001  https://www.ptt.cc/bbs/NBA/M.1642134299.A.362.html
# 5      arod1414  https://www.ptt.cc/bbs/NBA/M.1642134306.A.410.html
# 6    jackie0414  https://www.ptt.cc/bbs/NBA/M.1642134811.A.5A6.html
# 7         derwy  https://www.ptt.cc/bbs/NBA/M.1642135461.A.F0C.html
# 8       Bainite  https://www.ptt.cc/bbs/NBA/M.1642137120.A.5F8.html
# 9          MrDK  https://www.ptt.cc/bbs/NBA/M.1642137504.A.C3E.html
# 10        Rambo  https://www.ptt.cc/bbs/NBA/M.1642137739.A.0B5.html
# 11      MrSatan  https://www.ptt.cc/bbs/NBA/M.1642138029.A.D14.html
# 12   sodistrues  https://www.ptt.cc/bbs/NBA/M.1642138071.A.6A9.html
# 13      guardyo  https://www.ptt.cc/bbs/NBA/M.1642138204.A.239.html
# 14  RonArtest93  https://www.ptt.cc/bbs/NBA/M.1642139897.A.93D.html
# 15    s27052705  https://www.ptt.cc/bbs/NBA/M.1642140243.A.2D0.html
# 16    asd831129  https://www.ptt.cc/bbs/NBA/M.1642140361.A.6FA.html
# 17    zxc906383  https://www.ptt.cc/bbs/NBA/M.1642140822.A.5C4.html
# 18     mingonly  https://www.ptt.cc/bbs/NBA/M.1642141413.A.9C2.html
# 0     tim900127  https://www.ptt.cc/bbs/NBA/M.1642091943.A.05E.html
# 1    WeiBirdFan  https://www.ptt.cc/bbs/NBA/M.1642092216.A.8C4.html
# 2   willy911006  https://www.ptt.cc/bbs/NBA/M.1642093172.A.9F1.html
# 3       leonini  https://www.ptt.cc/bbs/NBA/M.1642093506.A.1F2.html
# 4      mingonly  https://www.ptt.cc/bbs/NBA/M.1642097235.A.197.html
# 5      LGNexus5  https://www.ptt.cc/bbs/NBA/M.1642111049.A.266.html
# 6        laptic  https://www.ptt.cc/bbs/NBA/M.1642118513.A.B6B.html
# 7        laptic  https://www.ptt.cc/bbs/NBA/M.1642120204.A.253.html
# 8        laptic  https://www.ptt.cc/bbs/NBA/M.1642120346.A.1A9.html
# 9      arod1414  https://www.ptt.cc/bbs/NBA/M.1642120507.A.D2F.html
# 10        sezna  https://www.ptt.cc/bbs/NBA/M.1642121936.A.BF3.html
# 11       laptic  https://www.ptt.cc/bbs/NBA/M.1642122112.A.12F.html
# 12  hanson90244  https://www.ptt.cc/bbs/NBA/M.1642125105.A.A6C.html
# 13       Bz5566  https://www.ptt.cc/bbs/NBA/M.1642125270.A.7DA.html
# 14       laptic  https://www.ptt.cc/bbs/NBA/M.1642127403.A.D1F.html
# 15        Rambo  https://www.ptt.cc/bbs/NBA/M.1642128400.A.F59.html
# 16       fliesa  https://www.ptt.cc/bbs/NBA/M.1642128606.A.A2C.html
# 0    GeorgeHill  https://www.ptt.cc/bbs/NBA/M.1642090192.A.76F.html
# 1      go190214  https://www.ptt.cc/bbs/NBA/M.1642090453.A.6E0.html
# 2   Wojnarowski  https://www.ptt.cc/bbs/NBA/M.1642091220.A.76F.html

# %%
df.shape[0]
# Out:
# 43
